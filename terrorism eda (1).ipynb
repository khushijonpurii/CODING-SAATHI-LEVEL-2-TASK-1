# %%
#Exploratory Data Analysis on Dataset - Terrorism

# %%
#As a security/defense analyst, try to find out the hot zone of terrorism.You can choose any of the tool of your choice (Python/R/Tableau/PowerBI/Excel/SAP/SAS)

# %%
#create dataframe
import pandas as pd
df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='iso-8859-1')
df
# Out:
# <ipython-input-7-98c911ba808c>:3: DtypeWarning: Columns (4,31,33,61,62,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='iso-8859-1')
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 48284  199109260051   1991       9    26        NaN         0        NaN
# 48285  199109260052   1991       9    26        NaN         0        NaN
# 48286  199109260053   1991       9    26        NaN         0        NaN
# 48287  199109260054   1991       9    26        NaN         0        NaN
# 48288  199109260055   1991       9    26        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 48284      159                Peru       3  ...      NaN    NaN    NaN
# 48285      159                Peru       3  ...      NaN    NaN    NaN
# 48286      159                Peru       3  ...      NaN    NaN    NaN
# 48287      159                Peru       3  ...      NaN    NaN    NaN
# 48288      159                Peru       3  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0         NaN      PGIS      0.0       0.0      0.0     0.0
# 1         NaN      PGIS      0.0       1.0      1.0     1.0
# 2         NaN      PGIS     -9.0      -9.0      1.0     1.0
# 3         NaN      PGIS     -9.0      -9.0      1.0     1.0
# 4         NaN      PGIS     -9.0      -9.0      1.0     1.0
# ...       ...       ...      ...       ...      ...     ...
# 48284     NaN      PGIS      0.0       0.0      0.0     0.0
# 48285     NaN      PGIS      0.0       0.0      0.0     0.0
# 48286     NaN      PGIS      0.0       0.0      0.0     0.0
# 48287     NaN      PGIS      0.0       0.0      0.0     0.0
# 48288     NaN       NaN      NaN       NaN      NaN     NaN
#
#                                                  related
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 48284  199109260051, 199109260022, 199109260023, 1991...
# 48285  199109260052, 199109260022, 199109260023, 1991...
# 48286  199109260053, 199109260022, 199109260023, 1991...
# 48287  199109260054, 199109260022, 199109260023, 1991...
# 48288                                                NaN
#
# [48289 rows x 135 columns]

# %%
df.shape #48289 rows 135 cols
# Out:
# (48289, 135)

# %%
df.size
# Out:
# 6519015

# %%
df.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
#check for missing values
missing_values = df.isnull().sum()

# %%
missing_values[missing_values > 0]
# Out:
# approxdate    48263
# resolution    47472
# provstate       196
# latitude       2606
# longitude      2606
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       43566
# Length: 107, dtype: int64

# %%
#col of intersest
selected_columns = ['iyear', 'imonth', 'iday', 'country_txt', 'region', 'INT_LOG', 'INT_IDEO']

# %%
#counts and unique values
for column in selected_columns:
    print("Column:", column)
    print(df[column].value_counts())
    print()
# Out:
# Column: iyear
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ba1ab8ba4187> in <cell line: 2>()
#       2 for column in selected_columns:
#       3     print("Column:", column)
# ----> 4     print(df[column].value_counts())
#       5     print()
#
# NameError: name 'df' is not defined

# %%
# Calc for selected columns
print("Descriptive statistics for selected columns:")
print(df[selected_columns].describe())
# Out:
# Descriptive statistics for selected columns:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-56cf3b4838f6> in <cell line: 3>()
#       1 # Calc for selected columns
#       2 print("Descriptive statistics for selected columns:")
# ----> 3 print(df[selected_columns].describe())
#
# NameError: name 'df' is not defined

# %%
#visualisation
import matplotlib.pyplot as plt

# %%
# Plot a bar chart of terrorism incidents by year
attacks_by_year = df['iyear'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
plt.bar(attacks_by_year.index, attacks_by_year.values)
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Terrorist Attacks by Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa15ebdfae62> in <cell line: 2>()
#       1 # Plot a bar chart of terrorism incidents by year
# ----> 2 attacks_by_year = df['iyear'].value_counts().sort_index()
#       3 plt.figure(figsize=(12, 6))
#       4 plt.bar(attacks_by_year.index, attacks_by_year.values)
#       5 plt.xlabel('Year')
#
# NameError: name 'df' is not defined

# %%
# Plot a pie chart of terrorism incidents by region
attacks_by_region = df['region'].value_counts()
plt.figure(figsize=(12,12))
plt.pie(attacks_by_region.values, labels=attacks_by_region.index, autopct='%1.1f%%')
plt.title('Terrorist Attacks by Region')
plt.show()
